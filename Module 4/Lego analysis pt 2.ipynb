# %% [markdown]
# # Lego analysis part 2

# %%
import pandas as pd
import sqlite3

# %%
connection = sqlite3.connect("lego_sets.db")

# %%
# Define the SQL query
query = """
SELECT *
FROM sets_with_themes;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#              set_num                                               name  year  \
# 0               00-1                                    Weetabix Castle  1970
# 1             0011-2                                  Town Mini-Figures  1978
# 2             0011-3                         Castle 2 for 1 Bonus Offer  1987
# 3             0012-1                                 Space Mini-Figures  1979
# 4             0013-1                                 Space Mini-Figures  1979
# ...              ...                                                ...   ...
# 11668    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...  2012
# 11669   WHITEHOUSE-1                                  Micro White House  2015
# 11670    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...  2010
# 11671  WishingWell-1                     Wishing Well [Toys R Us Promo]  2013
# 11672        wwgp1-1                Wild West Limited Edition Gift Pack  1996
#
# ...

# %%
# Define the SQL query
query = """
SELECT COUNT(*)
FROM sets_with_themes;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#    COUNT(*)
# 0     11673

# %%
# Define the SQL query
query = """
SELECT COUNT(parent_theme_id)
FROM sets_with_themes;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#    COUNT(parent_theme_id)
# 0                    8046

# %%
# Define the SQL query
query = """
SELECT DISTINCT theme_name
FROM sets_with_themes
ORDER BY theme_name;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#     theme_name
# 0          12V
# 1    4 Juniors
# 2         4.5V
# 3           9V
# 4       Advent
# ..         ...
# 381      X-Men
# 382      X-Pod
# 383      Xalax
# 384       Znap
# 385       eLAB
#
# [386 rows x 1 columns]

# %%
# Check whether each theme has a unique id

# Define the SQL query
query = """
SELECT COUNT(DISTINCT theme_name)
FROM sets_with_themes
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#    COUNT(DISTINCT theme_name)
# 0                         386

# %%
# Define the SQL query
query = """
SELECT COUNT(DISTINCT theme_id)
FROM sets_with_themes
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#    COUNT(DISTINCT theme_id)
# 0                       575

# %%
# See number of sets associated with each theme

# Define the SQL query
query = """
SELECT theme_name, COUNT(*) as set_count
FROM sets_with_themes
GROUP BY theme_name
ORDER BY set_count DESC;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df.head()
# Out:
#      theme_name  set_count
# 0  Supplemental        496
# 1       Technic        435
# 2          City        287
# 3       Friends        269
# 4     Basic Set        257

# %%
# Define the SQL query
query = """
SELECT theme_name, COUNT(*) as set_count
FROM sets_with_themes
GROUP BY theme_name
ORDER BY set_count;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df.head()
# Out:
#          theme_name  set_count
# 0       Control Lab          1
# 1      Ghostbusters          1
# 2  HO 1:87 Vehicles          1
# 3   Imperial Guards          1
# 4     Indiana Jones          1

# %%
# Check unique values within each group

query = """
SELECT theme_name, COUNT(DISTINCT theme_id) AS theme_count
FROM sets_with_themes
GROUP BY theme_name
ORDER BY theme_count DESC;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df.head(10)
# Out:
#      theme_name  theme_count
# 0  Supplemental           17
# 1          Fire           11
# 2       Airport           11
# 3       Traffic            9
# 4        Police            8
# 5        Harbor            8
# 6  Construction            8
# 7        Castle            8
# 8       Technic            6
# 9       Pirates            6

# %%
# Explore largest sets in each theme 

# Define the SQL query
query = """
SELECT theme_name, MAX(num_parts)
FROM sets_with_themes
GROUP BY theme_name;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df.head(10)
# Out:
#        theme_name  MAX(num_parts)
# 0             12V             784
# 1       4 Juniors              48
# 2            4.5V             497
# 3              9V             969
# 4          Advent             250
# 5  Advent Sub-Set              24
# 6     Adventurers              27
# 7          Agents            1153
# 8           Agori              17
# 9        Airjitzu             652

# %%
# Define the SQL query
query = """
SELECT *, MAX(num_parts)
FROM sets_with_themes
GROUP BY theme_name;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df.head(10)
# Out:
#    set_num                                               name  year  \
# 0   7740-1                         Inter-City Passenger Train  1980
# 1   4336-1                           Picture Frame and Mirror  1980
# 2   7722-1                         Steam Cargo Train, battery  1985
# 3  10173-1                                      Holiday Train  2006
# 4  40222-1                          24-in-1 Holiday Countdown  2016
# 5   4428-9  Advent Calendar 2012, City (Day 8) Wall with S...  2012
# 6   5381-1                           Adventurer's Accessories  1998
# 7   8635-1                   Mission 6: Mobile Command Center  2008
# 8   8974-1                                             Tarduk  2009
# 9  70590-1                            Airjitzu Battle Grounds  2016
#
#    num_parts  theme_id      theme_name  parent_theme_id  MAX(num_parts)
# 0        784       234             12V            233.0             784
# 1         48       279       4 Juniors              NaN              48
# ...

# %%
# Define the SQL query
query = """
SELECT *, MIN(num_parts)
FROM sets_with_themes
GROUP BY theme_name
ORDER BY num_parts;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df.head(10)
# Out:
#        set_num                                               name  year  \
# 0      66392-1    Duplo Cars Super Pack 3 in 1 (5816, 5817, 5818)  2012
# 1  Vancouver-1  LEGO Store Grand Opening Exclusive Set, Oakrid...  2012
# 2        240-1                    Wooden Storage Box Large, Empty  1967
# 3    5002946-1                                   Silver Centurion  2016
# 4      10623-1                               Basic Bricks – Large  2015
# 5        70904                              Clayface Splat Attack  2017
# 6       8559-1                                              Krana  2002
# 7        221-1                                       Idea Book #1  1973
# 8    4287744-1  City Value Pack - 7241 7246 - shrinkwrapped Ta...  2005
# 9        820-2  LegoWooden Storage Box Large (Double Latch) wi...  1966
#
#    num_parts  theme_id        theme_name  parent_theme_id  MIN(num_parts)
# 0         -1       506              Cars            504.0              -1
# ...

# %%
# Define the SQL query
query = """
SELECT theme_name, COUNT(*) as set_count, MIN(num_parts) AS min_parts, MAX(num_parts) AS max_parts, AVG(num_parts) AS avg_parts
FROM sets_with_themes
GROUP BY theme_name;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#     theme_name  set_count  min_parts  max_parts   avg_parts
# 0          12V         50          1        784  140.660000
# 1    4 Juniors          2          4         48   26.000000
# 2         4.5V         88          1        497  130.522727
# 3           9V         53          1        969  250.169811
# 4       Advent          3        228        250  239.333333
# ..         ...        ...        ...        ...         ...
# 381      X-Men          3          5        335  179.666667
# 382      X-Pod         19          4         57   40.684211
# 383      Xalax         16          1        112   13.062500
# 384       Znap         19         22        265   89.000000
# 385       eLAB          1        713        713  713.000000
#
# [386 rows x 5 columns]

# %%
# Define the SQL query
query = """
SELECT theme_name, COUNT(*) AS set_count
FROM sets_with_themes
GROUP BY theme_name
HAVING COUNT(*) > 50;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#                   theme_name  set_count
# 0                       4.5V         88
# 1                         9V         53
# 2             Advent Sub-Set         96
# 3                    Airport        172
# 4               Architecture         59
# 5                      Basic        106
# 6                Basic Model         92
# 7                  Basic Set        257
# 8                     Batman         93
# 9                   Bionicle         69
# 10                     Books         57
# 11                  Building         56
# 12               Bulk Bricks        125
# 13                    Castle         86
# 14                 Christmas         80
# 15                      City        287
# 16             Classic Basic         71
# 17             Classic Space         89
# 18                   Clikits        105
# 19              Construction        194
# 20                   Creator        249
# 21                Dimensions         58
# ...

# %%
# Filter for themes with 10 sets, then show avg number of parts in each

# Define the SQL query
query = """
SELECT theme_name, COUNT(theme_id) as set_count, AVG(num_parts) AS avg_parts
FROM sets_with_themes
GROUP BY theme_name
HAVING COUNT(theme_id) > 10
ORDER BY avg_parts DESC;
"""
# Execute the query and store the result in a DataFrame
df = pd.read_sql_query(query, connection)
df
# Out:
#                 theme_name  set_count    avg_parts
# 0        Modular Buildings         12  2350.583333
# 1               Sculptures         23  1716.695652
# 2        FIRST LEGO League         18  1387.000000
# 3               Model Team         16   683.187500
# 4                    Model         22   628.590909
# ..                     ...        ...          ...
# 221        DFB Minifigures         17     5.647059
# 222  Series 14 Minifigures         19     5.368421
# 223           Classic Town         11     3.818182
# 224        Power Functions         17     1.882353
# 225              Key Chain        132     0.181818
#
# [226 rows x 3 columns]
